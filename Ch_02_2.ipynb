# %% [markdown]
# <a href="https://colab.research.google.com/github/Li220Fish/DL-CLASS/blob/main/Ch_02_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **掛載雲端硬碟**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **import 套件**

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as plt_font
twfont1 = plt_font.FontProperties(fname="drive/MyDrive/DL_CLASS/msjh.ttc")
#動態顯示套件
from IPython import display

# %% [markdown]
# **定義多項式**

# %%
def F(x):
    return x**4-38*x**2-48*x+24

# %% [markdown]
# **定義導函式**

# %%
def F1(x):
    return 4*x**3-76*x-48

# %% [markdown]
# **用梯度下降尋找最小值**

# %%
#設定step_x、step_y用來儲存梯度下降每一步的座標
step_x=[]
step_y=[]
#設定學習率，可以調大或調小，觀察梯度下降情況
ETA=0.01
#設定梯度下降的起點，可以改變不同位置，觀察梯度下降情況
x_point=0
#開始梯度下降
for i in range(100):
  step_x.append(x_point)
  step_y.append(F(x_point))
  #利用梯度下降更新下一個x_point
  x_point=x_point-ETA*F1(x_point)

# %% [markdown]
# **用動畫一步一步展示梯度下降的更新情況**

# %%
for i in range(len(step_x)):
  plt.figure(figsize=(12,6))
  plt.title("動畫顯示梯度下降的移動路徑",fontproperties=twfont1,fontsize=20)
  x = np.linspace(-7,7, 10000)
  plt.plot(x, F(x))
  #畫出梯度下降的修正路徑點
  plt.scatter(step_x[:i],step_y[:i],s=20,color='r')
  #暫停0.1秒
  plt.pause(0.01)
  #清除目前的顯示
  display.clear_output(wait=True)
